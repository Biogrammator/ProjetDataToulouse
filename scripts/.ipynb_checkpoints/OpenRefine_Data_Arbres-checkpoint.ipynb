# %% [markdown]
# # Librairies

# %%
import polars as pl
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Chargement tableau

# %%
DIR="C:/Users/User/Documents/MesProjets/projet_python/AnalyseDataToulouse"

# %%
file = DIR + "/data/arbres_df_structure.csv"
df = pd.read_csv(file)

# %%
df
# Out:
#            id  longitude   latitude      famille    genre      espece  \
# 0       48662   1.379015  43.577712     Pinacees    Pinus       pinea
# 1       48665   1.379088  43.577605     Fagacees  Quercus       rubra
# 2       48666   1.379225  43.577732     Pinacees    Pinus       pinea
# 3       48667   1.379118  43.577559     Fagacees  Quercus       rubra
# 4       48674   1.377294  43.577680     Pinacees    Pinus       pinea
# ...       ...        ...        ...          ...      ...         ...
# 121130  51650   1.394111  43.583041    Malvacees    Tilia  x.europaea
# 121131  51654   1.393278  43.582888    Malvacees    Tilia  x.europaea
# 121132  51656   1.393232  43.582835    Malvacees    Tilia  x.europaea
# 121133  51689   1.398670  43.583979     Ulmacees    Ulmus      laevis
# 121134  51690   1.398718  43.583830  Cannabacees   Celtis   australis
#
#        cultivar_variete         stade_dev                               forme  \
# ...

# %% [markdown]
# # Connexion Base

# %% [markdown]
# Au préalable il faut réactiver la base de données. Dans mon cas personnel, il faut activer **PostgreSQl** via l'image **Docker** avec la commande:
#
# ```
# docker compose up -d
# ```
#
# On peut ensuite fermer l'image avec les modifications via:
#
#
# ```
# docker compose down -v
# ```

# %%
# Créer la connexion SQLAlchemy pour PostgreSQL
user = os.environ["PG_USER"]
password = os.environ["PG_PASSWORD"]

engine = create_engine(f"postgresql+psycopg2://{user}:{password}@localhost:5432/test_db")

# %%
# Écrire le dataframe dans PostgreSQL
df.to_sql("arbres", con=engine, if_exists="replace", index=False)
# Out:
# 135
